# %%
import numpy as np
from pathlib import Path
import os
import pandas as pd

root = Path('/hpc/group/kamaleswaranlab/EmoryDataset/Images/chest_xrays')
embedding_path = root / 'BioMedCLIP_embeddings'
supertable_path = root / 'matched_supertables_with_images'
supertable_template = "_timing_corrected.pickle"

# %%
supertables = list(supertable_path.glob("*" + supertable_template))
len(supertables)
# Out:
# 48194

# %%
import pickle

with open(root / 'supertable_stats.pickle', 'rb') as f:
    stats = pickle.load(f)

# %%
stats
# Out:
# {'age_min': np.int64(18),
#  'age_max': np.int64(121),
#  'age_nan': 0,
#  'cci9_min': np.float64(0.0),
#  'cci9_max': np.int64(14),
#  'cci9_nan': 0,
#  'cci10_min': np.float64(0.0),
#  'cci10_max': np.int64(81),
#  'cci10_nan': 2879,
#  'vent_rate_set_min': np.float64(-16.0),
#  'vent_rate_set_max': np.float64(647.0),
#  'vent_rate_set_nan': 35569,
#  'vent_tidal_rate_set_min': np.float64(-480.0),
#  'vent_tidal_rate_set_max': np.float64(5800.0),
#  'vent_tidal_rate_set_nan': 37282,
#  'vent_tidal_rate_exhaled_min': np.float64(0.0),
#  'vent_tidal_rate_exhaled_max': np.float64(7647.0),
#  'vent_tidal_rate_exhaled_nan': 33722,
#  'peep_min': np.float64(0.0),
#  'peep_max': np.float64(96.0),
#  'peep_nan': 35086,
#  'Oxygen_Flow_Rate_min': np.float64(-2.0),
#  'Oxygen_Flow_Rate_max': np.float64(99.0),
#  'Oxygen_Flow_Rate_nan': 6623,
#  'covid': 0,
#  'procedure': 5293,
#  'gender': Counter({'Male': 25685, 'Female': 22509}),
#  'race': Counter({'Caucasian or White': 24465,
#           'African American  or Black': 19429,
#           'Unknown, Unavailable or Unreported': 2423,
#           'Asian': 1396,
#           'Multiple': 231,
#           'American Indian or Alaskan Native': 149,
#           'Native Hawaiian or Other Pacific Islander': 101}),
#  'ethnicity': Counter({'Non-Hispanic or Latino': 42720,
#           'Unreported, Unknown, Unavailable': 3647,
#           'Hispanic or Latino': 1463,
#           'Not Recorded': 312,
#           'Unknown~Non-Hispanic': 33,
#           'Non-Hispanic~Unknown': 13,
#           'Unknown~Hispanic': 2,
#           'CD:1641210453': 1,
#           'CD:1642776725': 1,
#           'CD:1565395161': 1,
#           'CD:1719092855': 1}),
#  'icu_type': Counter({'cticu': 6490,
#           'ccu': 5332,
#           'micu': 5284,
#           'msicu': 4424,
#           'sicu BEFORE 1/18/2018; cticu ON OR AFTER 1/18/2018': 3546,
#           'neuro': 3229,
#           'cticu BEFORE 1/18/2018; micu ON OR AFTER 1/18/2018': 2272,
#           'sicu BEFORE 1/18/2018': 2098}),
#  'bed_type': Counter({'ward': 41314,
#           'icu': 26525,
#           'ed': 22629,
#           'other': 6143,
#           'or': 5305,
#           'obs': 72}),
#  'vent_mode': Counter({'AC/CMV Volume': 9718,
#           'CPAP+PS': 8395,
#           'NIPPV': 5489,
#           'ASV': 5061,
#           'CPAP': 3340,
#           'APV CMV': 2783,
#           'AC Pressure': 1763,
#           'APV SIMV': 1279,
#           'SIMV Volume': 929,
#           'CPAP, NIPPV': 371,
#           'Bi-Level/DuoPAP/APRV': 306,
#           'NIPPV AVAPS': 155,
#           'AC/CMV Volume, Other: VC+': 144,
#           'SIMV Pressure': 137,
#           'Other: VC+': 88,
#           'PRVC': 88,
#           'AC/CMV Volume, Other: ac/vc+': 57,
#           'AC/CMV Volume, CPAP+PS': 54,
#           'AC/CMV Volume, Other:': 53,
#           'Other: (S)CMV': 45,
#           'Other: S-CMV': 42,
#           'PAV+': 41,
#           'Other: T/C': 39,
#           'Other: SCMV': 33,
#           'CPAP+PS, NIPPV': 31,
#           'Other: (S) CMV': 29,
#           'Other: S CMV': 28,
#           'AC/CMV Volume, APV CMV': 28,
#           'ASV, CPAP+PS': 26,
#           'AC/CMV Volume, AC Pressure': 25,
#           'Other: S(CMV)': 23,
#           'Other: scmv': 20,
#           'Volume Support': 20,
#           'AC/CMV Volume, Other: AC/VC+': 20,
#           'Other: PCV': 18,
#           'NIPPV, Other: PCV': 17,
#           'HFOV': 17,
#           'Other: s cmv': 16,
#           'Date\\\\Time Correction': 15,
#           'AC/CMV Volume, SIMV Volume': 15,
#           'AC/CMV Volume, Other: vc+': 14,
#           'Other:': 14,
#           'CPAP+PS, Other:': 14,
#           'APV CMV, Other:': 13,
#           'ASV, AC/CMV Volume': 13,
#           'CPAP, Other: auto': 12,
#           'Other: trach collar': 11,
#           'Other: Trach Collar': 11,
#           'Other: (s)cmv': 11,
#           'Other: trach. collar': 10,
#           'Other: (s)CMV': 10,
#           'ASV, APV CMV': 10,
#           'Other: TRACH COLLAR': 10,
#           'NIPPV, Other: AVAPS': 10,
#           'Other: AVAPS': 10,
#           'Other: P-CMV': 10,
#           'Other: s-cmv': 9,
#           'Other: Standby': 9,
#           'NIPPV, Other: auto cpap': 9,
#           'ASV, Other:': 8,
#           'Date\\Time Correction': 8,
#           'AC/CMV Volume, SIMV Pressure': 8,
#           'Other: spont': 8,
#           'CPAP+PS, Other: pressure support wean': 7,
#           'Other: s(CMV)': 7,
#           'AC/CMV Volume, Other: AC/VC': 7,
#           'AC Pressure, Other:': 6,
#           'NIPPV, Other:': 6,
#           'AC Pressure, Other: ECMO': 6,
#           'Other: standby': 6,
#           'Other: p-cmv': 6,
#           'CPAP, CPAP+PS': 6,
#           'Other: Spont': 5,
#           'Other: (s) cmv': 5,
#           'APV CMV, Volume Support': 5,
#           'Other: stby': 5,
#           'Other: sbt': 4,
#           'Other: Volume Support': 4,
#           'Other: volume support': 4,
#           'Other: niv-st': 4,
#           'Other: Scmv': 4,
#           'Other: bipap': 4,
#           'Other: PCV+': 4,
#           'Other: (s) CMV': 4,
#           'AC/CMV Volume, Other: Vc+': 4,
#           'Other: PC': 4,
#           'NIPPV, Other: PC': 4,
#           'AC Pressure, APV CMV': 4,
#           'Other: tube compensation': 4,
#           'Other: p cmv': 4,
#           'Other: P CMV': 4,
#           'AC/CMV Volume, Other: AC/VC +': 4,
#           'AC Pressure, NIPPV': 4,
#           'AC Pressure, SIMV Pressure': 3,
#           'Other: S (CMV)': 3,
#           'Other: SBT': 3,
#           'Other: NIV-ST': 3,
#           'Other: s(cmv)': 3,
#           'NIPPV, Other: pcv': 3,
#           'Other: VS': 3,
#           'ASV, SIMV Volume': 3,
#           'NIPPV, Other: auto adjust': 3,
#           'AC/CMV Volume, Other: VC +': 3,
#           'Other: Autoset': 3,
#           'Other: Spontaneous': 3,
#           'Other: pcv': 3,
#           'Other: spontaneous': 3,
#           'Other: TC': 3,
#           'Other: avaps': 3,
#           'AC/CMV Volume, NIPPV': 3,
#           'CPAP+PS, SIMV Volume': 3,
#           'AC Pressure, Other: VV ECMO': 3,
#           'Other: Volume support': 3,
#           'AC Pressure, CPAP+PS': 3,
#           'APV CMV, SIMV Volume': 3,
#           'AC/CMV Volume, Bi-Level/DuoPAP/APRV': 3,
#           'Other: AC/VC+': 3,
#           'Other: (S) cmv': 3,
#           'Other: APV CMV': 3,
#           'AC/CMV Volume, Other: ac/vc+\\': 3,
#           'Other: vc+': 3,
#           'Other: PCMV': 3,
#           'Other: pcv+': 3,
#           'NIPPV, NIPPV AVAPS': 3,
#           'AC Pressure, Other: pediatric': 2,
#           'CPAP, Other:': 2,
#           'Other: S/CMV': 2,
#           'Other: ((S)CMV': 2,
#           'NIPPV, SIMV Volume': 2,
#           'Other: NIV- ST': 2,
#           'Other: auto cycle': 2,
#           'APV CMV, CPAP+PS': 2,
#           'AC/CMV Volume, Volume Support, Other:': 2,
#           'Other: S cmv': 2,
#           'AC/CMV Volume, Other: (S)CMV': 2,
#           'CPAP, Other: auto-cpap': 2,
#           'Other: APRV': 2,
#           'Other: AVAP': 2,
#           'NIPPV, Other: AVAPS mode': 2,
#           'AC/CMV Volume, Volume Support': 2,
#           'APV SIMV, SIMV Volume': 2,
#           'Other: Auto Adjust': 2,
#           'Other: NIV-st': 2,
#           'AC/CMV Volume, Other: ECMO': 2,
#           'Other: S-cmv': 2,
#           'CPAP+PS, SIMV Pressure': 2,
#           'NIPPV, Other: avaps': 2,
#           'AC/CMV Volume, AC Pressure, APV CMV': 2,
#           'CPAP+PS, Volume Support': 2,
#           'AC Pressure, PRVC': 2,
#           'Other: SIMV': 2,
#           'Other: CMV': 2,
#           'Other: PVC': 2,
#           'AC/CMV Volume, Other: CV+': 2,
#           'Other: auto': 2,
#           'Other: PSV': 2,
#           'AC/CMV Volume, Other: VC': 2,
#           'AC/CMV Volume, Other: S CMV': 2,
#           'CPAP, NIPPV, Other: auto': 2,
#           'NIPPV, Other: S/T': 2,
#           'Other: SCMV+': 2,
#           'Other: AutoCPAP': 2,
#           'NIPPV, Other: Auto CPAP': 2,
#           'Other: SIMV/CMV': 2,
#           'Other: SIMV CMV': 2,
#           'NIPPV, Other: auto CPAP': 2,
#           'AC/CMV Volume, Other: acvc+': 2,
#           'Other: (S0CMV': 2,
#           'CPAP, NIPPV, Other: Auto': 2,
#           'AC/CMV Volume, APV SIMV': 2,
#           'CPAP, Other: Auto': 2,
#           'Other: auto cpap': 2,
#           'Other: pcmv': 2,
#           'CPAP, Other: AUTO CPAP': 2,
#           'CPAP+PS, Other: found on PSV': 2,
#           'Other: s/cmv': 2,
#           'NIPPV, Other: Auto CPAP 5-20': 2,
#           'NIPPV, Other: Auto CPAP. Max pressure 20. Min pressure 5.': 2,
#           'Other: SPONT': 2,
#           'Other: AutoSet': 2,
#           'Other: ATC': 2,
#           'ASV, CPAP': 2,
#           'Other: MMV': 2,
#           'AC/CMV Volume, PRVC': 2,
#           'Other: (S)cmv': 2,
#           'NIPPV iVAPS': 2,
#           'Other: BIPAP': 2,
#           'ASV, NIPPV': 1,
#           'AC Pressure, Other: Pediatric mode': 1,
#           'NIPPV, Other: auto cpap 10/4': 1,
#           'AC/CMV Volume, Other: AcVc+': 1,
#           'Other: T-P': 1,
#           'Other: Passive AVAPs Home Vent': 1,
#           "Other: patient's home vent. trillogy": 1,
#           'Other: Pt. is on home trilogy ventilator': 1,
#           'Other: Pt. is on home triology ventilator': 1,
#           'Other: Home(trilogy) vent': 1,
#           'Other: Home(trilogy)': 1,
#           'Other: Home(trilogy) vent settings': 1,
#           'Other: home trilogy ventilator': 1,
#           'Other: HFNC': 1,
#           'Other: SCMV; changes per attending MD, Dr. Daniels': 1,
#           'Other: Vauto': 1,
#           'CPAP, NIPPV, Other: auto cpap': 1,
#           'NIPPV, Other: C-flex': 1,
#           'AC Pressure, Other: pt found on PC': 1,
#           'Other: VAuto': 1,
#           'NIPPV, Other: V Auto': 1,
#           'Bi-Level/DuoPAP/APRV, Other:': 1,
#           'NIPPV, Other: CPAP': 1,
#           'Other: Auto cycle': 1,
#           'CPAP, Other: AUTO CPAP 5-20': 1,
#           'Other: Standby; patient took mask off and turned off equipment.': 1,
#           'Other: trach': 1,
#           'AC/CMV Volume, Other: S-CMV': 1,
#           'Other: S CMV. Pts RR increasing 35-40': 1,
#           'Other: s(Cmv)': 1,
#           'AC/CMV Volume, Other: ACVC +': 1,
#           'CPAP, Other: home CPAP': 1,
#           'CPAP, Other: Auto Cpap': 1,
#           'CPAP, Other: Auto CPAP 5-20cm H2O': 1,
#           'Other: S -CMV': 1,
#           'Other: Pressure Support Wean': 1,
#           'Other: Pt on V60 ST mode.': 1,
#           'NIPPV, Other: Auto CPAP. Max 20. Min 5.': 1,
#           'Other: AVAPS, Vt=450,Pmin=10, Pmax - 25': 1,
#           'Other: AVAPS mode, Vt = 450, Pmin = 10. Pmax = 25': 1,
#           'Other: AVAPS mode, Vt = 450, Pmin = 10, Pmax = 25': 1,
#           'Other: bagged': 1,
#           'AC/CMV Volume, Other: (s) cmv': 1,
#           'APV CMV, Other: Pressure support trial ended times three hours. patient placed back on ventilator.': 1,
#           'AC Pressure, Other: In back up mode, apnea ventilation.': 1,
#           'NIPPV, SIMV Pressure': 1,
#           'CPAP, Other: AUTO': 1,
#           'NIPPV, Other: Auto CPAP. Maximum 20. Minimum 5.': 1,
#           'CPAP, Other: Auto Adjust': 1,
#           'Other: Spontaneous - SBT': 1,
#           'APV CMV, CPAP+PS, HFOV': 1,
#           'CPAP+PS, Other: auto': 1,
#           'NIPPV, Other: CPAP flex': 1,
#           'Other: VS+': 1,
#           'Other: Standby - patient does not want to keep mask on.': 1,
#           'CPAP+PS, Other: SPONTANEOUS': 1,
#           'Other: PC IRV': 1,
#           'Other: Pressure control': 1,
#           'AC Pressure, CPAP': 1,
#           'Other: AUTOPAP': 1,
#           'Other: Prssure control': 1,
#           'CPAP+PS, Other: spont': 1,
#           'AC/CMV Volume, Other: VC+_': 1,
#           'CPAP, Other: auto adusting': 1,
#           'Other: s-CMV': 1,
#           'Other: pt extubated to 5 LPM HFNC. no complications noted': 1,
#           'AC/CMV Volume, PAV+': 1,
#           'Other: Auto CPAP 10-4': 1,
#           'Other: Auto set': 1,
#           'CPAP+PS, Other: found on Pressure Support': 1,
#           'Other: autoset 12/4': 1,
#           'CPAP+PS, Other: SPONT': 1,
#           'APV CMV, Other: mode changed per md': 1,
#           'NIPPV AVAPS, Other: AVAPS': 1,
#           "Other: S/B - Patient didn't tolerate.": 1,
#           'CPAP, Other: pt has a lot of secretions pt is unable to effectively cough up secretions RN and Resident are aware that this can lead to possible aspiration and wants to trial cpap in spite of.': 1,
#           'Other: placed on n/c @5l/m per ccm': 1,
#           'NIPPV, Other: Home Resmed': 1,
#           'CPAP+PS, Other: Increased PS from 6 to 12': 1,
#           'Other: T/c': 1,
#           'AC Pressure, APV CMV, APV SIMV': 1,
#           'Other: VT/PC': 1,
#           'Other: standby; patient agreed to cpap and then refused after device set up. Device left at bedside.': 1,
#           'Other: PT refused requested for machine to be pulled from room to prevent charges. V-60 found in room': 1,
#           'Other: Standby - Patient was vomiting today.': 1,
#           'Other: t-collar': 1,
#           'Other: T COLLAR VIA G5': 1,
#           'APV SIMV, CPAP+PS': 1,
#           'Other: pt found on NC': 1,
#           'Other: Equipment bedside; patient refused to wear.': 1,
#           'Other: HF THROUGH BIPAP (AIRVO)': 1,
#           'Other: HF': 1,
#           'AC/CMV Volume, Other: Rate found on 15': 1,
#           'Other: py on AVAPS/ST': 1,
#           'Other: s(CMV': 1,
#           'Other: (s)': 1,
#           'Other: Home settings.': 1,
#           'AC Pressure, APV CMV, PRVC': 1,
#           'Other: volume support.': 1,
#           'Other: Volume Support.': 1,
#           'CPAP+PS, HFOV': 1,
#           'Other: Pt off unit in surgery': 1,
#           'AC/CMV Volume, Other: (S) CMV': 1,
#           'Other: on standby at this time': 1,
#           'Other: cp/ps 10/6': 1,
#           'Other: psv 12/6/.3': 1,
#           'Other: psv 12/6': 1,
#           'APV CMV, Other: (S)CMV+': 1,
#           'NIPPV, Other: auto cpap, 15/7': 1,
#           'AC/CMV Volume, Other: Ac/VC +': 1,
#           'CPAP+PS, Other: spontan/sage changed vent mode': 1,
#           'AC Pressure, Volume Support': 1,
#           'Other: [PC 10': 1,
#           'Other: pc 10': 1,
#           'Other: Pressure Support Trial': 1,
#           'NIPPV AVAPS, Other: per family at bedside with screenshot of settings': 1,
#           'Bi-Level/DuoPAP/APRV, Other: APRV': 1,
#           'NIPPV, Other: auto': 1,
#           'NIPPV, Other: auto pap 5-12 cmH2O': 1,
#           'CPAP, Other: AUTO TITRATE': 1,
#           'NIPPV, Other: autoset': 1,
#           'NIPPV AVAPS, Other: avaps pc': 1,
#           'Other: pt. on home Trilogy ventilator': 1,
#           'Other: pt. on home ventilator: Trilogy': 1,
#           'Other: Tilogy': 1,
#           'Other: Trilogy': 1,
#           'AC/CMV Volume, AC Pressure, SIMV Pressure, Other:': 1,
#           'APV CMV, Other: Switched to RATE at this time': 1,
#           'CPAP+PS, Other: Pt placed on CPAP +PS at this time': 1,
#           'NIPPV, Other: Pressure Conmtrol': 1,
#           'Other: n/c': 1,
#           'Other: Standby - Patient wants to wear nasal cannula instead.': 1,
#           'Other: Standby - Patient refuses to wear at this time.': 1,
#           'CPAP, Other: refused': 1,
#           'CPAP, Other: Auto adjust': 1,
#           'Other: NIIV ST': 1,
#           'NIPPV, Other: on trilogy': 1,
#           'Other: pt is on trilogy on AVAPS': 1,
#           'NIPPV, Other: Auto CPAP. Min pressure +5. Max pressure +20.': 1,
#           'Other: AVAPS: Min. Pres.= 15, Max. Pres. = 30,': 1,
#           'Other: FOCUS': 1,
#           'NIPPV, Other: Auto mode': 1,
#           'Other: auto-CPAP': 1,
#           'Other: Auto-CPAP': 1,
#           'AC Pressure, APV SIMV': 1,
#           'CPAP, NIPPV, Other: auto cpap 4-10': 1,
#           'NIPPV, Other: Cflex': 1,
#           'AC/CMV Volume, CPAP, CPAP+PS': 1,
#           'Other: (S)C,V': 1,
#           'Other: simv/cmv': 1,
#           'Other: PSV 16/6/.3': 1,
#           'Other: psv to 6/6': 1,
#           'Other: S- CMV': 1,
#           'Other: )S) Cmv': 1,
#           'Other: BIPAoff at this time.': 1,
#           'Other: spont 15/6/35%': 1,
#           'Other: pt off bipap': 1,
#           'Other: spon': 1,
#           'Other: spont 10/8/0.40': 1,
#           'Other: Standby; patient declined to use tonight.': 1,
#           'NIPPV, Other: NIPPV/PC': 1,
#           'Other: 8/6': 1,
#           'NIPPV, Other: Auto CPAP. Maximum pressure 20. Minimum pressure 4.': 1,
#           'Other: APRV                             T-High: 1.5, T-Low: 0.5       P-High: 40, P-Low: 14': 1,
#           'Other: trach.collar': 1,
#           'NIPPV, Other: Auto CPAP. Maximum pressure 20. Minimum pressure 6.': 1,
#           'Other: AutoCPAP programmed to 4-15.': 1,
#           'Other: Auto CPAP/ CFLEX 4-14 cmH20': 1,
#           'Other: Auto-Cpap': 1,
#           'Other: SCMV. patient bucking the vent on APVcmv mode.': 1,
#           'Other: stand by': 1,
#           'Other: stand-by': 1,
#           'Other: Stand-by': 1,
#           'Other: AVAa': 1,
#           'AC Pressure, NIPPV AVAPS': 1,
#           'Other: PC AVAPS': 1,
#           'Other: pc AVAPS': 1,
#           'AC Pressure, SIMV Volume': 1,
#           'Other: PS': 1,
#           'Other: S-CVM': 1,
#           'ASV, Other: see intervention note': 1,
#           'AC/CMV Volume, CPAP': 1,
#           'Other: PS 10/6': 1,
#           'CPAP, Other: AUTO-CPAP: high=15 low=8': 1,
#           'Other: STBY': 1,
#           'NIPPV, Other: pressure control': 1,
#           'APV CMV, Other: (S)CMV': 1,
#           'Other: S(cmv)': 1,
#           'ASV, Other: adjustments made by MD': 1,
#           'CPAP, Other: auto Pap 5-12cmH2O': 1,
#           'CPAP, Other: auto Cpap  Max12 Min 5': 1,
#           'Other: trach collar trials': 1,
#           'Other: TRach collar': 1,
#           'Other: p_CMV': 1,
#           'Other: TV': 1,
#           'APV SIMV, Volume Support': 1,
#           'NIPPV, Other: Auto Set mode': 1,
#           'NIPPV, Other: Auto CPAP 6-15': 1,
#           'Other: APRV T. low - 0.6 P High - 28  P low - 5 T High  3.5': 1,
#           'Other: Decreased T High to 2.4': 1,
#           'Other: APRV T Low 0.6 T High 2.4 P 28 P Low 5': 1,
#           'Other: NIV/ST': 1,
#           'Other: NIV S/T': 1,
#           'NIPPV, Other: NIV-ST': 1,
#           'Other: NIV_ST': 1,
#           'Other: niv st': 1,
#           'Other: niv': 1,
#           'Other: niv/st': 1,
#           'Other: nip': 1,
#           'Other: NIIV-ST': 1,
#           'Other: NIPPV': 1,
#           'Other: NIV': 1,
#           'NIPPV, Other: niv-st': 1,
#           'Other: NIV ST': 1,
#           'Other: NivST': 1,
#           'Other: NIV -ST': 1,
#           'Other: NIV- S/T': 1,
#           'Other: Intellicuff': 1,
#           'Other: NIV+ST': 1,
#           'Other: NIV  ST': 1,
#           'Other: Niv ST': 1,
#           'Other: Home Settings NIV ST': 1,
#           'Other: Niv-st': 1,
#           'Other: cpap on standby in pt room': 1,
#           'Other: spontanueous': 1,
#           'AC/CMV Volume, Other: VA ECMO': 1,
#           'CPAP, Other: SPONT': 1,
#           'Other: AC Passive mode': 1,
#           'Other: other(s cmv': 1,
#           'APV CMV, Volume Support, Other:': 1,
#           'APV CMV, Other: ECMO': 1,
#           'CPAP+PS, Other: PER MD': 1,
#           'Other: trach collar with airvo': 1,
#           'AC/CMV Volume, Other: Pt. placed on VC+. NP aware of changes': 1,
#           'CPAP, Other: auto Cpap    Max P 20/ Min p 8': 1,
#           'Other: AutoCPAP with 10-20cmH2O with 3L bled in': 1,
#           'CPAP, NIPPV, Other: Auto-CPAP': 1,
#           'CPAP+PS, Other: for SBT. Patient tidal volume 100-134 ml on 0/6. 5/6 used for SBT per Dr.M. Noto orders.': 1,
#           'Other: stby NIPPV': 1,
#           'Other: trach. collar - cuff deflated per ccm.': 1,
#           'NIPPV, Other: AutoCPAP': 1,
#           'CPAP, Other: Patient placed on SBT per CCM attending.': 1,
#           'CPAP, Other: Autoset': 1,
#           'Other: Pressure Support': 1,
#           'CPAP, Other: 4-18': 1,
#           'CPAP, Other: 4-18 cm H2O': 1,
#           'Other: 100% Tube Compensation': 1,
#           'Other: s- cmv': 1,
#           'NIPPV, Other: AUTO CPAP 5-12 cmH20': 1,
#           'CPAP, Other: flex, auto cpap max20, min 5': 1,
#           'Other: auto CPAP': 1,
#           'CPAP, Other: auto  Cpap  max 12  min 8': 1,
#           'CPAP, Other: Auto Cpap  Max P- 12  Min- P-8': 1,
#           'AC/CMV Volume, Other: acv/c+': 1,
#           'APV CMV, Other: ac/vc+': 1,
#           'Other: CMV +': 1,
#           'ASV, APV SIMV': 1,
#           'Other: CFlex': 1,
#           'Other: CFLEX': 1,
#           'NIPPV, Other: cflex': 1,
#           'Other: V-30': 1,
#           'Other: V30': 1,
#           'Other: SIMV-VC': 1,
#           'Other: SIMV Volume': 1,
#           'Other: Simv Volume': 1,
#           'NIPPV, Other: ABG drawn on 100% while baqgging': 1,
#           'Other: P-cmv': 1,
#           'Other: p-CMV': 1,
#           'APV SIMV, CPAP, CPAP+PS': 1,
#           'Other: Stand by': 1,
#           'NIPPV, Other: Auto CPAP. Maximum pressure-15. Minimum pressure -6.': 1,
#           'Other: AUTO CPAP': 1,
#           'Other: Auto Cpap': 1,
#           'Other: Automatic Tube Compensaion': 1,
#           'Other: tc': 1,
#           'APV CMV, PAV+, SIMV Pressure': 1,
#           'NIPPV, Other: cpap': 1,
#           'Other: VC++': 1,
#           'Other: started on stand-by for bronch.': 1,
#           'NIPPV, Other: Pt found on AVAPS': 1,
#           'ASV, AC Pressure': 1,
#           'Other: pressure support wean': 1,
#           'ASV, Other: Patient completed SBT for one hour.': 1,
#           'AC Pressure, Other: PCV+': 1,
#           'Other: SBT started': 1,
#           'Other: CPAP+PS': 1,
#           'Other: pressure con': 1,
#           'CPAP+PS, Other: received on CPAP/PS 5/7': 1,
#           'Other: awaps': 1,
#           'Other: SBT 0/0': 1,
#           'Other: Spont - 6/6': 1,
#           'AC/CMV Volume, SIMV Pressure, SIMV Volume': 1,
#           'Other: (s) cmv`': 1,
#           'Other: SPT': 1,
#           'Other: Pressure CMV': 1,
#           'Other: pc-cmv': 1,
#           'Other: P-Cmv': 1,
#           'Other: Aerosol trach collar': 1,
#           'CPAP, Other: AUTO  CPAP': 1,
#           'Other: SBT.': 1,
#           'CPAP, Other: pt on APAP 14-20. pt stated her setting at home is 14': 1,
#           'Other: On Standby - patient is not ready to go on.': 1,
#           'Other: On Standby': 1,
#           'Other: Standby - Patient refuses at this time due to pain; RN notified.': 1,
#           'APV CMV, Other: VC+': 1,
#           'NIPPV, Other: ST': 1,
#           'CPAP, NIPPV, Other: Auto CPAP 8-10 cmH2O': 1,
#           'CPAP, NIPPV, Other: Auto CPAP 8-10': 1,
#           'NIPPV, Other: home cpap with O2 bled in': 1,
#           'AC/CMV Volume, Other: a/vc+': 1,
#           'Other: Trach Co;;ar': 1,
#           'APV CMV, PAV+': 1,
#           'Other: S/B - patient not ready yet.': 1,
#           'CPAP, Other: Auto-Cpap': 1,
#           'AC/CMV Volume, Other: ac/c+': 1,
#           'Other: T-Piece': 1,
#           'Other: press control\\\\assist': 1,
#           'Other: t collar via vent': 1,
#           'Other: Patient was offered a CPAP but refuses to wear one.': 1,
#           'Other: Pt refused': 1,
#           'Other: Standby - patient refused.': 1,
#           'Other: Standby - patient refused toight.': 1,
#           'Other: Standby at bedside.': 1,
#           'AC/CMV Volume, Other: Ac/vc =': 1,
#           'NIPPV, Other: IVAPS': 1,
#           'NIPPV, Other: IVAPS, Resp. Med': 1,
#           'Other: s cmc': 1,
#           'Other: PC/NIPPV': 1,
#           'Other: stby Nippv': 1,
#           'AC/CMV Volume, Other: per MD': 1,
#           'Other: (S) CMV`': 1,
#           'Other: (S)': 1,
#           'AC/CMV Volume, Other: Ac/vc +': 1,
#           'CPAP+PS, Other: pressure support trial': 1,
#           'Other: bagging with 100% FIO2 c peep valve @12': 1,
#           'CPAP, Other: auto cpap max 15, min 5': 1,
#           'CPAP, NIPPV, Other: Auto CPAP 15/5': 1,
#           'AC Pressure, Other: p-cmv': 1,
#           'AC Pressure, Other: pcmv': 1,
#           'AC/CMV Volume, Other: ac/vc+.': 1,
#           'Bi-Level/DuoPAP/APRV, Other: APRV   PH 35,  PL 0,  TH 3.4,  TL 0.4': 1,
#           'Bi-Level/DuoPAP/APRV, Other: APRV  PH 33, PL 0, TH 3.6m  TL 0.6': 1,
#           'AC/CMV Volume, Other: ac/vc': 1,
#           'Other: Trach collar trail ended. Patient placed back on prior settings.': 1,
#           'APV SIMV, Volume Support, Other:': 1,
#           'NIPPV, Other: Pressure Control': 1,
#           'NIPPV, Other: PVC': 1,
#           'NIPPV, PAV+': 1,
#           'NIPPV, Other: took pt off bipap. no issues or complications': 1,
#           'CPAP+PS, Other: not tolerated at this time.': 1,
#           'Other: PCCMV': 1,
#           'Other: PcMV': 1,
#           'NIPPV, Other: auto CPAP 6-12': 1,
#           'Other: S/T mode (vision BiPAP)': 1,
#           'ASV, AC Pressure, APV CMV': 1,
#           'AC Pressure, Other: per provider': 1,
#           'Other: VC': 1,
#           'CPAP, Other: Autocpap 5 to 20': 1,
#           'CPAP, NIPPV, Other: auto CPAP Max 20, Min 5': 1,
#           'CPAP, NIPPV, Other: Auto CPAP 5-20': 1,
#           'CPAP, Other: Auto CPAP 5-20 cmh20': 1,
#           'CPAP, Other: auto cpap 5-20': 1,
#           'CPAP, Other: auto 5-20': 1,
#           'CPAP, Other: Auto 20 high 5 low': 1,
#           'Other: Home Unit Autocycle CPAP': 1,
#           'AC/CMV Volume, Other: AC?VC +': 1,
#           'Other: PCV+PS': 1,
#           'Other: PSV+PS': 1,
#           'Other: pcv+ps': 1,
#           'APV CMV, APV SIMV': 1,
#           'NIPPV, Other: Auto Set CPAP': 1,
#           'Other: PAP S/T': 1,
#           'Other: self adjusting': 1,
#           'AC/CMV Volume, Other: AC/VC  67FLOW': 1,
#           'CPAP, Other: Volume Support': 1,
#           'Other: Volume support.': 1,
#           'CPAP, Other: VS': 1,
#           'Other: vent on standby': 1,
#           'Other: autoset': 1,
#           'NIPPV, Other: Auto-Set': 1,
#           'Other: Sponta': 1,
#           'Other: NIPPV PCV': 1,
#           'NIPPV, Other: PC/NIV': 1,
#           'CPAP, Other: auto cpap 4-10': 1,
#           'SIMV Volume, Other:': 1,
#           'SIMV Volume, Other: with TC': 1,
#           'Bi-Level/DuoPAP/APRV, Volume Support': 1,
#           'NIPPV, Other: AutoSet; min P 5cmH2O, max P 15 cmH2O': 1,
#           'CPAP, Other: Auto adjusting': 1,
#           'CPAP, NIPPV, Other: AUTO CPAP MAX 14 MIN 5': 1,
#           'Other: spontaneous mode. patient is now comfort care.': 1,
#           'CPAP+PS, Other: Spont': 1,
#           'AC/CMV Volume, Other: aac/vc+': 1,
#           'Other: airvo': 1,
#           'AC/CMV Volume, Other: VC+ mode was discontinued - resumed regular VC mode.': 1,
#           'NIPPV, Other: Pressure control': 1,
#           'Other: bmv': 1,
#           'Other: S/T': 1,
#           'NIPPV, Other: emerg med': 1,
#           'Other: APAP Max IPAP: 20, Min EPAP 4, Ti Max: 2 sec, Ti Min: 0.8 sec': 1,
#           'Other: home ventilator': 1,
#           'Other: Home Ventilator': 1,
#           'Other: Home Vent': 1,
#           'Other: Trilogy-Home Vent.': 1,
#           'Other: Home Vent.': 1,
#           'Other: home vent': 1,
#           'Other: Home Ventilator , Triology': 1,
#           'Other: STANDBY': 1,
#           'Other: spont, MD changed setting': 1,
#           'AC Pressure, Other: VA ECMO': 1,
#           'NIPPV, Other: PSV': 1,
#           'CPAP, Other: auto cpap 6-20': 1,
#           'CPAP+PS, Other: 8PEEP/10PS  SBT': 1,
#           'Other: PCV +': 1,
#           'Other: PVC+': 1,
#           'Other: pcv +': 1,
#           'Other: PCA+': 1,
#           'Other: pvc+': 1,
#           'Other: APAP': 1,
#           'CPAP, Other: auto-CPAP': 1,
#           'NIPPV, Other: Auto CPAP 4-15 cmH2O': 1,
#           'Other: Vent on stand by tonight.': 1,
#           'Other: Vent on standby tonight.': 1,
#           'Other: vent discontinued - pt expired': 1,
#           'CPAP, NIPPV, Other: Auto Cpap': 1,
#           'NIPPV, Other: auto pap 5-10cm H2O': 1,
#           'CPAP, Other: auto cpap 15/6': 1,
#           'CPAP, Other: auto CPAP': 1,
#           'Other: Auto CPAP': 1,
#           'Other: Auto  cpap   Max. P-15/ Min P. 6': 1,
#           'Other: Auto cpap MAX 15, Min 6': 1,
#           'CPAP, NIPPV, Other: auto cpap, 20 over 14': 1,
#           'Other: Patient is placed on Pressure Support trial.': 1,
#           'CPAP, NIPPV, Other: autoset minimum 4 maximum 12. 4L O2 bleed in.': 1,
#           'Other: atc': 1,
#           'NIPPV, Other: Auto CPAP. Max pressure 20. Min pressure 6.': 1,
#           'Other: auto cpap 20/6': 1,
#           'Other: st': 1,
#           'CPAP, Other: CPAP flex 6-15 cmH20': 1,
#           'SIMV Volume, Other: PS': 1,
#           'CPAP, Other: Autoset 5-15': 1,
#           'Other: s': 1,
#           'Other: Standby; patient refused.': 1,
#           'Other: On standby; patient removed mask.': 1,
#           'Other: Pressure support by NP Bri Perry.': 1,
#           'AC/CMV Volume, Other: AC/VC to give more flow to patient': 1,
#           'AC/CMV Volume, Other: ac/vc flow added.': 1,
#           'AC/CMV Volume, Other: AC/VC, FLOW ADJUSTED.': 1,
#           'Other: S(CMV)+': 1,
#           'CPAP+PS, Other: PS of 12 from 15.': 1,
#           'Other: 10 of PS per APP change.': 1,
#           'SIMV Pressure, SIMV Volume': 1,
#           'AC Pressure, CPAP+PS, Other: Pt currently apneic, backup mode PC is running curently': 1,
#           'Other: PCV on V60': 1,
#           'Other: Tube compensation': 1,
#           'Other: tube compensation for recruitment': 1,
#           'Other: Tube Compensation': 1,
#           'Other: tube compentsation': 1,
#           'NIPPV, Other: auto CPAP 6-10': 1,
#           'Other: ST': 1,
#           'Other: SIMV(CMV)': 1,
#           'Other: simv/CMV': 1,
#           'ASV, Other: Patient placed back on ventilator at prior settings.': 1,
#           'Other: pt extubated to HFNC @ 10L': 1,
#           'Other: pcv/assist': 1,
#           'Other: PCV/Assist': 1,
#           'Other: PCV/ASSIST': 1,
#           'CPAP, SIMV Volume': 1,
#           'AC/CMV Volume, Other: AC\\VC +': 1,
#           'NIPPV, Other: bipap 10/6, rr 12 fi02 32%': 1,
#           'CPAP+PS, Other: BIPAP': 1,
#           'NIPPV, Other: BiPaP': 1,
#           'Other: s -cmv': 1,
#           'Other: S-CMYV': 1,
#           'CPAP+PS, Other: ps trial': 1,
#           'AC/CMV Volume, Other: I-vent': 1,
#           'Other: Heated High Flow with Flolan.': 1,
#           'Other: S- CMV, pt placed on settings per David RRT, due to dyssynchrony.': 1,
#           'Other: off, Extubated': 1,
#           'Other: Spontaneous mode': 1,
#           'Other: Auto C Flex': 1,
#           'NIPPV, Other: self adjusting': 1,
#           'Other: 55L airvo': 1,
#           'Other: home unit': 1,
#           'Other: spont 10/6/.3': 1,
#           'ASV, Other: attempted TC trial @ 15lpm and 50% after uneventful > 2hours on spontaneous mode with excellent volumes and mechanics. pt c/o sob and tightness breathing. pt denies any chest pain.  pt trach was suctrioned, trach care done, inner cannula re...': 1,
#           'AC/CMV Volume, HFOV': 1,
#           'Other: PC+': 1,
#           'Other: ST Spot Mode': 1,
#           'HFOV, Other:': 1,
#           'NIPPV, Other: P/C': 1,
#           'Other: Patient placed on prior settings.': 1,
#           'Other: ASV': 1,
#           'Other: bagging w/ peep valve': 1,
#           'ASV, AC/CMV Volume, CPAP+PS': 1,
#           'Other: SPONT +PS': 1})}

# %%
selected_columns = [
    #Vitals
    'temperature',
    'daily_weight_kg',
    'sbp', 'dbp',
    'pulse', 'unassisted_resp_rate',
    'spo2', 'end_tidal_co2',
    'Oxygen_Flow_Rate',  'best_map',
    #'pulse_pressure', removing because linear combination sbp - dbp
    'pf_sp', 'pf_pa',

    
    #Labs
    'anion_gap', 'base_excess',
    'bicarb_(hco3)', 'blood_urea_nitrogen_(bun)',
    'calcium','calcium_adjusted','calcium_ionized', 'chloride',
    'creatinine','glucose','magnesium','phosphorus',
    'potassium','sodium','hematocrit','hemoglobin',         
    'platelets',
    'white_blood_cell_count',
    'alanine_aminotransferase_(alt)',
    'albumin',
    'alkaline_phosphatase',
    'ammonia',
    'aspartate_aminotransferase_(ast)',
    'bilirubin_direct',
    'bilirubin_total',
    'fibrinogen',
    'inr',
    'lactate_dehydrogenase',
    'partial_prothrombin_time_(ptt)',
    'protein',
    'lipase',
    'troponin',
    'fio2',
    #'partial_pressure_of_carbon_dioxide_(paco2)',
    #'partial_pressure_of_oxygen_(pao2)', Removing these two because correlated with pf_pa, pf_sp
    'ph',
    'saturation_of_oxygen_(sao2)',  'n_to_l',
    
    'gcs_total_score',

    #Vasopressors
    'norepinephrine',
    'epinephrine',
    'dobutamine',
    'dopamine',
    'phenylephrine',
    'vasopressin',

    #Other data  
    'covid',  #Removing vent_status because same as on_vent
    'icu', #Flag
    'procedure', #Flag 
    'on_pressors',
    'on_dobutamine',
    'on_dialysis',
    'elapsed_icu',
    'elapsed_hosp',
    'on_vent',
    'age',
    'gender',
    'race',
    'ethnicity',
    'cci9',
    'cci10',
    'infection',
    'sepsis',
    
    'bed_type', #Ward/ICU string
    'icu_type', #ICU type string
    

    'vent_mode',
    'vent_rate_set',
    'vent_tidal_rate_exhaled',
    'peep', #'vent_fio2' somehow less accurate than fio2
     'cxr_timing',
     'cxr_timing_approx_flag'
]

imputation_strategy = {
    #Vitals
    'temperature' : [37, 'FeedForward', 36, 38],  
    'daily_weight_kg': [None, 'FeedForward', 60, 90],
    'sbp_selected': [90, 'FeedForward', 90, 130], 
    'dbp_selected': [60, 'FeedForward', 65, 75],
    'pulse': [75, 'FeedForward', 60, 90], 
    'unassisted_resp_rate': [17, 'FeedForward', 10, 24],
    'spo2': [98, 'FeedForward', 95, 100], 
    'end_tidal_co2': [None, None, 35, 45],
    'Oxygen_Flow_Rate': [None, 'FeedForward6', 0, 70, 0, 70],  
    'best_map': [70, 'FeedForward', 65, 75],
    'pf_sp': [None, 'FeedForward24', 300, 500], 
    'pf_pa': [None, 'FeedForward24', 400, 500],

    
    #Labs
    'anion_gap' : [None, 'FeedForward24', 8, 12], 
    'base_excess': [None, 'FeedForward24', -2, 2],
    'bicarb_(hco3)': [None, 'FeedForward24', 22, 27], 
    'blood_urea_nitrogen_(bun)': [None, 'FeedForward24', 6, 20],
    'calcium' : [None, 'FeedForward24', 8.5, 10.5], #'calcium_adjusted',
    'calcium_ionized': [None, 'FeedForward24', 1, 1.3], 
    'chloride': [None, 'FeedForward24', 96, 106],
    'creatinine': [None, 'FeedForward24', 0.5, 1.3],
    'glucose': [None, 'FeedForward24', 60, 200],
    'magnesium': [None, 'FeedForward24', 1.5, 2.5],
    'phosphorus': [None, 'FeedForward24', 2.5, 4.5],
    'potassium': [None, 'FeedForward24', 3.5, 4.5],
    'sodium': [None, 'FeedForward24', 135, 145],
    'hematocrit': [None, 'FeedForward24', 35, 45],
    'hemoglobin': [None, 'FeedForward24', 12, 17],         
    'platelets': [None, 'FeedForward24', 150, 450],
    'white_blood_cell_count': [None, 'FeedForward24', 4, 11],
    'alanine_aminotransferase_(alt)': [None, 'FeedForward24', 4, 36],
    'albumin': [None, 'FeedForward24', 3.4, 5.4],
    'alkaline_phosphatase': [None, 'FeedForward24', 44, 147],
    'ammonia': [None, 'FeedForward24', 15, 45],
    'aspartate_aminotransferase_(ast)': [None, 'FeedForward24', 8, 33],
    'bilirubin_direct': [None, 'FeedForward24', 0.1, 0.4],
    'bilirubin_total': [None, 'FeedForward24', 0.2, 1.2],
    'fibrinogen': [None, 'FeedForward24', 200, 400],
    'inr': [None, 'FeedForward24', 0.8, 1.3],
    'lactate_dehydrogenase': [None, 'FeedForward24', 105, 350],
    'partial_prothrombin_time_(ptt)': [None, 'FeedForward24', 25, 35],
    'protein': [None, 'FeedForward24', 6, 8.3],
    'lipase': [None, 'FeedForward24', 1, 160],
    'troponin': [None, 'FeedForward24', 0, 0.03],
    'fio2': [None, 'FeedForward24', 21, 40],
    #'partial_pressure_of_carbon_dioxide_(paco2)',
    #'partial_pressure_of_oxygen_(pao2)', Removing these two because correlated with pf_pa, pf_sp
    'ph': [None, 'FeedForward24', 7.35, 7.45],
    'saturation_of_oxygen_(sao2)': [None, 'FeedForward24', 95, 100],  
    'n_to_l' : [None, 'FeedForward24', 0, 100],
    
    'gcs_total_score': [15, 'FeedForward24', 1, 15],

    #Vasopressors
    #'norepinephrine',
    #'epinephrine',
    #'dobutamine',
    #'dopamine',
    #'phenylephrine',
    #'vasopressin',

    #Other data  
    'covid':[0, 0, 0, 1],  #Removing vent_status because same as on_vent
    'icu':[0, 0, 0, 1], #Flag
    'procedure': [0, 0, 0, 1], #Flag 
    'on_pressors':[0, 0, 0, 1],
    'on_dobutamine': [0, 0, 0, 1],
    'on_dialysis': [0, 0, 0, 1],
    'elapsed_icu': [0, None, None, None],
    'elapsed_hosp': [0, None, None, None],
    'on_vent': [0, 0, 0, 1],
    'age': [None, None, 18, 100],
    'gender': [None, None, 'Onehot'],
    'race': [None, None, 'Onehot'],
    ##'ethnicity': [None, None, 'Onehot'],
    'cci9': [None, None, 0, 100],
    'cci10': [None, None, 0, 100],
    'infection': [0,0, 0, 1],
    'sepsis': [0,0, 0, 1],
    
    'bed_type': [None, None, 'Onehot'], #Ward/ICU string
    'icu_type': [None, None, 'Onehot'], #ICU type string
    

    ##'vent_mode': [None, 'FeedForwardVO', 'Onehot'],
    'vent_rate_set': [None, 'FeedforwardVO',0, 100, 0, 600],
    'vent_tidal_rate_exhaled': [None, 'FeedForwardVO', 0, 500],
    'peep': [None, 'FeedForwardVO', 5, 15], #'vent_fio2' somehow less accurate than fio2
    #'cxr_timing',
    # 'cxr_timing_approx_flag'
    
}

# %%
def process_icu_type(df):
    icu_types_in_df = df.icu_type.unique()
    
    if 'sicu BEFORE 1/18/2018; cticu ON OR AFTER 1/18/2018' in icu_types_in_df:
        indices = df.loc[df.icu_type == 'sicu BEFORE 1/18/2018; cticu ON OR AFTER 1/18/2018'].index
        if indices[0] > pd.to_datetime('1/18/2018'): 
            df.loc[indices, 'icu_type'] = 'cticu'
        else:
            df.loc[indices, 'icu_type'] = 'sicu'
    if 'cticu BEFORE 1/18/2018; micu ON OR AFTER 1/18/2018' in icu_types_in_df:
        indices = df.loc[df.icu_type == 'cticu BEFORE 1/18/2018; micu ON OR AFTER 1/18/2018'].index 
        if indices[0] > pd.to_datetime('1/18/2018'): 
            df.loc[indices, 'icu_type'] = 'micu'
        else:
            df.loc[indices, 'icu_type'] = 'cticu'
    
    if 'sicu BEFORE 1/18/2018' in icu_types_in_df:
        indices = df.loc[df.icu_type == 'sicu BEFORE 1/18/2018'].index 
        if indices[0] > pd.to_datetime('1/18/2018'): 
            df.loc[indices, 'icu_type'] = np.nan
        else:
            df.loc[indices, 'icu_type'] = 'sicu'
    return df['icu_type'].values

def process_race(df):
    if df.race.values[0] in ['Multiple', 'Unknown, Unavailable or Unreported']:
        return [np.nan]*len(df)

def process_bedtype(df):
    other_indices = df.loc[df.bed_type == 'other']
    if len(other_indices) > 0:
        df.loc[other_indices, 'bed_type'] = np.nan
    return df['bed_type'].values

# %%
def bp_selector(row):
    """
    Selects "line" or "cuff" measurements for blood pressure.  
    """
    if row[['sbp_line','dbp_line']].notnull().all() and (row['sbp_line'] - row['dbp_line']) > 15:
        return row['sbp_line'], row['dbp_line']
    elif row[['sbp_cuff','dbp_cuff']].notnull().all() and (row['sbp_cuff'] - row['dbp_cuff']) > 15 :
        return row['sbp_cuff'], row['dbp_cuff']
    else:
        return np.nan, np.nan

# %%
def process_dataframes(df, imputation_strategy, stats_dict=None):
    """
    Process dataframes according to the imputation strategy.
    
    Args:
        df: pandas DataFrame to process
        imputation_strategy: dictionary containing processing rules
        stats_dict: dictionary containing stats for one-hot encoding (optional)
    """
    
    def onehot_encode(df, column_name, final_stats):
        nan_mask = df[column_name].isna()
        df[column_name] = pd.Categorical(df[column_name], categories = list(final_stats[column_name].keys()))
        dummies = pd.get_dummies(df[column_name], prefix=column_name, columns=list(final_stats[column_name].keys()))
        if nan_mask.any():
            dummies.loc[nan_mask] = 0
        return pd.concat([df, dummies], axis=1)

    # First, select only columns that are in imputation_strategy
    columns_to_process = [col for col in df.columns if col in imputation_strategy]
    df_processed = df[columns_to_process].copy()
    
    # First pass: Handle initial missing values and value bounds
    for col in columns_to_process:
        strategy = imputation_strategy[col]
        # Handle 5th and 6th elements if they exist (value bounds)
        if len(strategy) >= 6:
            min_bound, max_bound = strategy[4], strategy[5]
            mask = (df_processed[col] < min_bound) | (df_processed[col] > max_bound)
            df_processed.loc[mask, col] = np.nan
        
        # Handle initial missing values
        initial_value = strategy[0]
        if initial_value is not None:
            # If all values are missing, fill entire column
            if df_processed[col].isna().all():
                df_processed[col] = initial_value
            else:
                # Find first non-null value and fill everything before it
                first_valid = df_processed[col].first_valid_index()
                if first_valid is not None:
                    df_processed.loc[:first_valid, col] = initial_value
    
    # Second pass: Handle imputation strategies
    for col in columns_to_process:
        strategy = imputation_strategy[col]
        impute_method = strategy[1]
        
        if impute_method == 'FeedForward':
            df_processed[col] = df_processed[col].ffill()
        
        elif impute_method == 'FeedForward24':
            df_processed[col] = df_processed[col].ffill(limit=24)
        
        elif impute_method == 'FeedForward6':
            df_processed[col] = df_processed[col].ffill(limit=6)
        
        elif impute_method == 'FeedForwardVO':
            temp_series = df_processed[col].copy()
    
            # Get indices where we have valid values
            valid_indices = temp_series.dropna().index

            for valid_idx in valid_indices:
                # Only process if we're in a vent-on period
                if df_processed.loc[valid_idx, 'on_vent'] == 1:
                    # Find next vent off or next valid value after this point
                    next_indices = df_processed.index[df_processed.index > valid_idx]
                    if len(next_indices) > 0:
                        next_off = next_indices[
                            (df_processed.loc[next_indices, 'on_vent'] == 0) |
                            (~temp_series.loc[next_indices].isna())
                        ].min() if len(next_indices) > 0 else len(df_processed)

                        # Forward fill from this valid value until next off/valid
                        temp_series.loc[valid_idx:next_off] = temp_series.loc[valid_idx:next_off].ffill()

            df_processed[col] = temp_series
        
        elif impute_method == 0:
            df_processed[col] = df_processed[col].fillna(0)
    
    # Third pass: Handle normalization and one-hot encoding
    for col in columns_to_process:
        strategy = imputation_strategy[col]
        
        if strategy[2] == 'Onehot':
            if stats_dict is not None:
                df_processed = onehot_encode(df_processed, col, stats_dict)
        elif strategy[2] is not None and strategy[3] is not None:
            # Min-max normalization
            min_val, max_val = strategy[2], strategy[3]
            try:
                df_processed[col] = (df_processed[col] - min_val) / (max_val - min_val)
            except:
                print(col, min_val, max_val)
    return df_processed

# %% [markdown]
# ### Add Imaging

# %%
from scipy.interpolate import interp1d

embedding_path = root / 'BioMedCLIP_embeddings'

supertable_template = "_timing_corrected_processed.pickle"
supertables = list(supertable_path.glob("*" + supertable_template))
len(supertables)
# Out:
# 48194

# %%
df = pd.read_pickle(supertables[0])
df
# Out:
#                      temperature  daily_weight_kg     pulse  \
# 2015-04-16 19:30:00          0.5              NaN  0.500000
# 2015-04-16 20:30:00          0.5              NaN  0.500000
# 2015-04-16 21:30:00          0.5              NaN  1.500000
# 2015-04-16 22:30:00          0.5              NaN -0.300000
# 2015-04-16 23:30:00          0.5              NaN -0.300000
# ...                          ...              ...       ...
# 2015-04-21 04:30:00          0.2             1.22  0.000000
# 2015-04-21 05:30:00          0.2             1.22  0.000000
# 2015-04-21 06:30:00         -0.1             1.22 -0.233333
# 2015-04-21 07:30:00         -0.1             1.22 -0.233333
# 2015-04-21 08:30:00         -0.1             1.22 -0.233333
#
#                      unassisted_resp_rate  spo2  end_tidal_co2  anion_gap  \
# 2015-04-16 19:30:00              0.500000   0.6            NaN        NaN
# 2015-04-16 20:30:00              0.500000   0.6            NaN        0.5
# 2015-04-16 21:30:00              0.428571   0.8            NaN        0.5
# 2015-04-16 22:30:00              0.428571   0.6           -3.3        0.5
# 2015-04-16 23:30:00              0.428571   0.6            NaN        0.5
# ...                                   ...   ...            ...        ...
# 2015-04-21 04:30:00              0.714286   0.4            NaN        NaN
# 2015-04-21 05:30:00              0.714286   0.4            NaN        NaN
# 2015-04-21 06:30:00              0.714286   0.4            NaN        NaN
# 2015-04-21 07:30:00              0.714286   0.4            NaN        NaN
# 2015-04-21 08:30:00              0.714286   0.4            NaN        NaN
#
#                      base_excess  bicarb_(hco3)  blood_urea_nitrogen_(bun)  \
# 2015-04-16 19:30:00          NaN            NaN                        NaN
# 2015-04-16 20:30:00          NaN            0.6                   0.285714
# 2015-04-16 21:30:00          NaN            0.6                   0.285714
# 2015-04-16 22:30:00          NaN            0.6                   0.285714
# 2015-04-16 23:30:00          NaN            0.6                   0.285714
# ...                          ...            ...                        ...
# 2015-04-21 04:30:00          NaN            NaN                        NaN
# 2015-04-21 05:30:00          NaN            NaN                        NaN
# 2015-04-21 06:30:00          NaN            NaN                        NaN
# 2015-04-21 07:30:00          NaN            NaN                        NaN
# 2015-04-21 08:30:00          NaN            NaN                        NaN
#
#                      ...  bed_type_or  bed_type_obs  icu_type_cticu  \
# 2015-04-16 19:30:00  ...            0             0               0
# 2015-04-16 20:30:00  ...        False         False               0
# 2015-04-16 21:30:00  ...        False         False               0
# 2015-04-16 22:30:00  ...        False         False               0
# 2015-04-16 23:30:00  ...        False         False               0
# ...                  ...          ...           ...             ...
# 2015-04-21 04:30:00  ...        False         False               0
# 2015-04-21 05:30:00  ...        False         False               0
# 2015-04-21 06:30:00  ...        False         False               0
# 2015-04-21 07:30:00  ...        False         False               0
# 2015-04-21 08:30:00  ...        False         False               0
#
#                      icu_type_micu  icu_type_neuro  icu_type_ccu  \
# 2015-04-16 19:30:00              0               0             0
# 2015-04-16 20:30:00              0               0             0
# 2015-04-16 21:30:00              0               0             0
# 2015-04-16 22:30:00              0               0             0
# 2015-04-16 23:30:00              0               0             0
# ...                            ...             ...           ...
# 2015-04-21 04:30:00              0               0             0
# 2015-04-21 05:30:00              0               0             0
# 2015-04-21 06:30:00              0               0             0
# 2015-04-21 07:30:00              0               0             0
# 2015-04-21 08:30:00              0               0             0
#
#                      icu_type_msicu  cxr_timing  cxr_timing_approx_flag  \
# 2015-04-16 19:30:00               0        None                    None
# 2015-04-16 20:30:00               0        None                    None
# 2015-04-16 21:30:00               0        None                    None
# 2015-04-16 22:30:00               0        None                    None
# 2015-04-16 23:30:00               0        None                    None
# ...                             ...         ...                     ...
# 2015-04-21 04:30:00               0        None                    None
# 2015-04-21 05:30:00               0        None                    None
# 2015-04-21 06:30:00               0        None                    None
# 2015-04-21 07:30:00               0        None                    None
# 2015-04-21 08:30:00               0        None                    None
#
#                                                           encounter_id
# 2015-04-16 19:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
# 2015-04-16 20:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
# 2015-04-16 21:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
# 2015-04-16 22:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
# 2015-04-16 23:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
# ...                                                                ...
# 2015-04-21 04:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
# 2015-04-21 05:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
# 2015-04-21 06:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
# 2015-04-21 07:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
# 2015-04-21 08:30:00  7c9832ae9005681cb88a87816d63c70060b1a97e2a922a...
#
# [110 rows x 85 columns]

# %%
object_columns = [column for column in df.columns if not pd.api.types.is_numeric_dtype(df[column])]
object_columns = [column for column in object_columns if column not in ['cxr_timing', 'encounter_id']]

# %%
for column in object_columns:
    df[column] = df[column].astype('float64')

# %%
dtypes = [df[column].dtype for column in df.columns]

# %%
list(zip(df.columns, dtypes))
# Out:
# [('temperature', dtype('float64')),
#  ('daily_weight_kg', dtype('float64')),
#  ('pulse', dtype('float64')),
#  ('unassisted_resp_rate', dtype('float64')),
#  ('spo2', dtype('float64')),
#  ('end_tidal_co2', dtype('float64')),
#  ('anion_gap', dtype('float64')),
#  ('base_excess', dtype('float64')),
#  ('bicarb_(hco3)', dtype('float64')),
#  ('blood_urea_nitrogen_(bun)', dtype('float64')),
#  ('calcium', dtype('float64')),
#  ('calcium_ionized', dtype('float64')),
#  ('chloride', dtype('float64')),
#  ('creatinine', dtype('float64')),
#  ('glucose', dtype('float64')),
#  ('magnesium', dtype('float64')),
#  ('phosphorus', dtype('float64')),
#  ('potassium', dtype('float64')),
#  ('sodium', dtype('float64')),
#  ('hematocrit', dtype('float64')),
#  ('hemoglobin', dtype('float64')),
#  ('platelets', dtype('float64')),
#  ('white_blood_cell_count', dtype('float64')),
#  ('alanine_aminotransferase_(alt)', dtype('float64')),
#  ('albumin', dtype('float64')),
#  ('alkaline_phosphatase', dtype('float64')),
#  ('ammonia', dtype('float64')),
#  ('aspartate_aminotransferase_(ast)', dtype('float64')),
#  ('bilirubin_direct', dtype('float64')),
#  ('bilirubin_total', dtype('float64')),
#  ('fibrinogen', dtype('float64')),
#  ('inr', dtype('float64')),
#  ('lactate_dehydrogenase', dtype('float64')),
#  ('partial_prothrombin_time_(ptt)', dtype('float64')),
#  ('protein', dtype('float64')),
#  ('lipase', dtype('float64')),
#  ('troponin', dtype('float64')),
#  ('fio2', dtype('float64')),
#  ('ph', dtype('float64')),
#  ('saturation_of_oxygen_(sao2)', dtype('float64')),
#  ('covid', dtype('float64')),
#  ('gcs_total_score', dtype('float64')),
#  ('icu', dtype('float64')),
#  ('procedure', dtype('float64')),
#  ('best_map', dtype('float64')),
#  ('pf_sp', dtype('float64')),
#  ('pf_pa', dtype('float64')),
#  ('n_to_l', dtype('float64')),
#  ('on_pressors', dtype('float64')),
#  ('on_dobutamine', dtype('float64')),
#  ('elapsed_icu', dtype('int64')),
#  ('elapsed_hosp', dtype('float64')),
#  ('on_vent', dtype('float64')),
#  ('age', dtype('float64')),
#  ('cci9', dtype('float64')),
#  ('cci10', dtype('float64')),
#  ('on_dialysis', dtype('float64')),
#  ('infection', dtype('float64')),
#  ('sepsis', dtype('float64')),
#  ('Oxygen_Flow_Rate', dtype('float64')),
#  ('vent_tidal_rate_exhaled', dtype('float64')),
#  ('vent_rate_set', dtype('float64')),
#  ('peep', dtype('float64')),
#  ('sbp_selected', dtype('float64')),
#  ('dbp_selected', dtype('float64')),
#  ('gender_Male', dtype('bool')),
#  ('gender_Female', dtype('bool')),
#  ('race_Caucasian or White', dtype('float64')),
#  ('race_African American  or Black', dtype('float64')),
#  ('race_Asian', dtype('float64')),
#  ('race_Native Hawaiian or Other Pacific Islander', dtype('float64')),
#  ('race_American Indian or Alaskan Native', dtype('float64')),
#  ('bed_type_ward', dtype('float64')),
#  ('bed_type_icu', dtype('float64')),
#  ('bed_type_ed', dtype('float64')),
#  ('bed_type_or', dtype('float64')),
#  ('bed_type_obs', dtype('float64')),
#  ('icu_type_cticu', dtype('float64')),
#  ('icu_type_micu', dtype('float64')),
#  ('icu_type_neuro', dtype('float64')),
#  ('icu_type_ccu', dtype('float64')),
#  ('icu_type_msicu', dtype('float64')),
#  ('cxr_timing', dtype('O')),
#  ('cxr_timing_approx_flag', dtype('float64')),
#  ('encounter_id', dtype('O'))]

# %%
df['cxr_trajectory_endpoints'] = [0]*len(df)

# %%
df.loc[df['cxr_timing'].first_valid_index(): df['cxr_timing'].last_valid_index(), 'cxr_trajectory_endpoints'] = 1

# %%
df['cxr_timing_ffill'] = df['cxr_timing'].ffill()

# %%
interpolated_embeddings = np.zeros((len(df), 512))

# %%
recorded_cxr_index = np.where(df.cxr_timing.values != None)[0]

# %%
for idx in recorded_cxr_index:
    path = embedding_path / (df.iloc[idx]['cxr_timing'] + '.npy')
    if path.exists():
        embedding = np.load(path)
        interpolated_embeddings[idx, :] = embedding
    else:
        print("No such file: ", path)

# %%
for i in range(len(recorded_cxr_index)-1):
    start_idx = recorded_cxr_index[i]
    end_idx = recorded_cxr_index[i+1]
    v1 = interpolated_embeddings[start_idx]
    v2 = interpolated_embeddings[end_idx]
    n_steps = end_idx - start_idx
    weights = np.arange(1, n_steps) / n_steps
    interpolated_embeddings[start_idx+1:end_idx] = v1 + weights.reshape(-1, 1) * (v2 - v1)

# %%
# Out:
# array([[ -1.88171816,  -3.88081431, -24.46614456, ...,  -0.17376935,
#          -3.70242667,  -0.52481449],
#        [ -1.90837222,  -3.81346272, -24.40264664, ...,  -0.16588222,
#          -3.65594695,  -0.51140139],
#        [ -1.93502628,  -3.74611113, -24.33914871, ...,  -0.15799509,
#          -3.60946723,  -0.4979883 ],
#        ...,
#        [ -3.18776717,  -0.58058639, -21.35474625, ...,   0.21270004,
#          -1.42492042,   0.13242707],
#        [ -3.21442123,  -0.5132348 , -21.29124832, ...,   0.22058717,
#          -1.37844071,   0.14584017],
#        [ -3.24107529,  -0.44588321, -21.2277504 , ...,   0.2284743 ,
#          -1.33196099,   0.15925326]])
