# %%
from pathlib import Path
import pydicom
import os
import matplotlib.pyplot as plt

path = Path("/hpc/group/kamaleswaranlab/mimic/physionet.org/files/mimic-cxr/2.1.0/files/p10")

# %%
files = os.listdir(path)

# %%
os.listdir(path / files[0])
# Out:
# ['index.html', 's55232289.txt', 's55232289']

# %%
images = os.listdir(path/ files[0] / 's55232289')

# %%
img = pydicom.dcmread(path / files[0] / 's55232289' / '88a78f7-e2bec3a2-d44e1948-c627a046-195d5b10.dcm')
# Out:
# ['688a78f7-e2bec3a2-d44e1948-c627a046-195d5b10.dcm',
#  'index.html',
#  'e3dc5573-3057eb39-6db40699-7cd3dcb0-c551ddcf.dcm']

# %%
img = pydicom.dcmread(path / files[0] / 's55232289' / '688a78f7-e2bec3a2-d44e1948-c627a046-195d5b10.dcm')

# %%
img
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 204
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Computed Radiography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.138958702056791339299303292000742645830
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.55362949469033348352269585565668676650
# (0002, 0013) Implementation Version Name         SH: 'MIMIC-CXR v2.0.0'
# -------------------------------------------------
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY', 'POST_PROCESSED', '', '', '', '', '', '100000']
# (0008, 0016) SOP Class UID                       UI: Computed Radiography Image Storage
# ...

# %%
dir(img)
# Out:
# ['AccessionNumber',
#  'AcquisitionDate',
#  'AcquisitionDeviceProcessingDescription',
#  'AcquisitionNumber',
#  'AcquisitionTime',
#  'AnnotationDisplayFormatID',
#  'BitsAllocated',
#  'BitsStored',
#  'BodyPartExamined',
#  'BorderDensity',
#  'BurnedInAnnotation',
#  'Columns',
#  'ContentDate',
#  'ContentTime',
#  'DeidentificationMethod',
#  'DeidentificationMethodCodeSequence',
#  'FilmOrientation',
#  'GraphicAnnotationSequence',
#  'HighBit',
#  'ImageDisplayFormat',
#  'ImageType',
#  'ImagerPixelSpacing',
#  'InstanceNumber',
#  'LossyImageCompression',
#  'Manufacturer',
#  'Modality',
#  'PatientBirthDate',
#  'PatientID',
#  'PatientIdentityRemoved',
#  'PatientName',
#  'PatientOrientation',
#  'PatientSex',
#  'PerformedProcedureStepDescription',
#  'PhotometricInterpretation',
#  'PixelData',
#  'PixelRepresentation',
#  'PixelSpacing',
#  'PositionerType',
#  'PresentationLUTShape',
#  'ProcedureCodeSequence',
#  'ReferringPhysicianName',
#  'RequestingService',
# ...

# %%
plt.imshow(img.pixel_array, cmap = 'grey')
plt.show()
